# %% [markdown]
# # Module Objectives
# In this module, you will be introduced to the process of working with files as well as handling any errors you may run into when writing code. By the end of this section you will be able to:
# - Use the `os` module to interface with your computers operating system
# - Read and write to files
# - Learn to work with different file formats (csv and json) and the modules used to handle them
# - Handle any errors that come up in your code

# %% [markdown]
# # The OS module
# The `OS` module in Python provides functions for interacting with the operating system. This module provides a portable way of using operating system-dependent functionality like changing the working directory, creating directories, locating files in a directory and more.
# ---
# To get started using the `os` module, you can import it with the following command:
# ```python
# import os
# ```

# %%
import os

# %% [markdown]
# # Creating Paths
# Paths are how computers are able to locate files and directories. You can join two or more pathname components, inserting `/` as needed using the `os.path.join` method.
# --
#
# ### Example
# ```python
# path = os.path.join('Python', 'Files', 'OS module')
# print(path) -> "Python/Files/OS module"
#
# path = os.path.join(path, 'creating paths')
# print(path) -> "Python/Files/OS module/creating paths"
# ```

# %%
#TODO create a path 
path = os.path.join('folder','oliver','elias')
path
# Out:
# 'folder/oliver/elias'

# %% [markdown]
# # Creating directories
# If we want to have python create a new directory for us, we can do so using the `makedirs` function. The `os.makedirs()` method in Python is used to create a directory recursively. That means while making your base directory, if any intermediate-level directory is missing, os.makedirs() method will create them all.
# ---
#
# ### Example
# ```python
# path = "5. Files and Exceptions/5.1 Reading and writing to files/new directory
# os.makedirs(path)
# ```

# %%
def create_directories():
  try:
    os.makedirs('sample/directory1')
    os.makedirs('sample/directory2/subdirectory')
    os.makedirs('sample/directory3/subdirectory/finaldirectory')
    print("Directories created successfully!")
  except Exception as e:
    print("There was an error")
    raise e

create_directories()
# Out:
# Directories created successfully!

# %% [markdown]
# # What directory are we working in?
# A directory is a collection of files and subdirectories, in other words, a directory is just a folder on your computer. When you want to interact with a folder on your computer, you can do that in the `File Explorer` if you're on windows or the `Finder` if you're on mac. In either of these programs it is easy to tell which folder you're working in because it is the folder that is currently open, for which you can see its contents. Writing code to interface with a computers filesystem is not as straightforward as it is when using a GUI like `windows file explorer` or `Mac finder`. When working with filesystems in any programming language, you always want to know which directory you are working in. Otherwise you could write files to the wrong locations or get file not found errors. We can check the current working directory using the `os.getcwd` method.
#
#
# ```python
# import os
# print(os.getcwd()) -> '/Python-Course/Modules/5. Files and Exceptions/5.1 Reading and writing to files'
# ```

# %%
#TODO print the current working directory
os.getcwd()
# Out:
# '/content'

# %% [markdown]
# # Changing directories
# Now that we can verify our working directory in python, we can move around our file system by using the `os.chdir` method. This method expects a single argument which is a path that points to a new directory on our computer.
# ---
#
# ```python
# os.chdir('sample/directory1')
# print(os.getcwd()) -> 'sample/directory1'
# ```
#
# *When you change your working directory, all file operations that you do will be done in the directory you've changed to unless you specify that you want to operate in a different location.*
# ---

# %%
#TODO Change directories to the sample directory1
os.chdir('content/sample/directory1')
os.getcwd()
# Out:
# '/content/sample/directory1'

# %% [markdown]
# If you are in a subdirectory and want to move up a level (to the parent directory) you can do so by prepending `..` to your file path. The `..` means *'go up one directory'*
# ---
#
# ```python
# print(os.getcwd()) -> 'sample/directory1'
# path = '../'
# os.chdir(path)
# print(os.getcwd()) -> 'sample'
# ```

# %%
#TODO go up to the parent directory from within directory1
os.getcwd()
os.chdir("..")
os.getcwd()
# Out:
# '/'

# %% [markdown]
# # Listing files and directories
# The `os.listdir()` method in python is used to get the list of all files and directories in the specified directory. If we don’t specify any directory, then list of files and directories in the current working directory will be returned.
#
# ```python
# # list files and directories in the working dorectory
# entities = os.listdir()
# print(entities) -> ['sample', 'directory1', 'directory2', etc...]
#
# # list files and directories in a specific directory
# entities = os.listdir('5.1 Reading and writing to files')
# print(entities) -> ['files_demo.ipynb', 'sample', etc...]
# ```

# %%
#TODO list the files and directories in the working directory
os.listdir()
#TODO list the files and directories in the '/' (root) directory
os.listdir("/")
#TODO use a for loop to print out the files and directories along with the index of each entity
for index, entity in enumerate(os.listdir("/")):
  print(f"({index})({entity})")
# Out:
# (0)(dev)
# (1)(opt)
# (2)(bin)
# (3)(tmp)
# (4)(run)
# (5)(proc)
# (6)(media)
# (7)(root)
# (8)(usr)
# (9)(sys)
# (10)(mnt)
# (11)(home)
# (12)(srv)
# (13)(var)
# (14)(lib64)
# (15)(boot)
# (16)(lib)
# (17)(etc)
# (18)(sbin)
# (19)(content)
# (20)(.dockerenv)
# (21)(tools)
# (22)(datalab)
# (23)(tensorflow-1.15.2)
# (24)(python-apt)
# (25)(lib32)

# %% [markdown]
# # Listing all files and directories
# Given a directory path, If you want to list all of the files, directories, and subdirectories in that path, you can use the `os.walk` method. This method takes a path as a required argument, however, there are other optional argument but we're not going to go into those. The `path` argument is the root path that you want to start at and the `walk` method will recursively list every entity in the root path. It returns a 3 element tuple where the elements are `(root, directories, files)`.
#
# ```python
# for root, directories, files in os.walk(os.getcwd()):
#     print(root, directories, files)
# ```

# %%
#TODO Walk the current directory and list everything
for root, subdirs, files in os.walk("/"):
  print(f"Root:{root}")
  print(f"Subdirs:{subdirs}")
  print(f"Files:{files}\n")
# Out:
# Streaming output truncated to the last 5000 lines.
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v1/layers/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v1/train
# Subdirs:['queue_runner', 'experimental', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v1/train/queue_runner
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v1/train/queue_runner/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v1/train/experimental
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v1/train/experimental/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v1/train/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v1/config
# Subdirs:['optimizer', 'experimental', 'threading', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v1/config/optimizer
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v1/config/optimizer/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v1/config/experimental
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v1/config/experimental/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v1/config/threading
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v1/config/threading/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v1/config/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v1/sets
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v1/sets/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v1/metrics
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v1/metrics/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v1/graph_util
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v1/graph_util/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2
# Subdirs:['strings', 'summary', 'quantization', 'sysconfig', 'bitwise', 'linalg', 'debugging', 'autograph', 'xla', 'lite', 'raw_ops', 'nest', 'saved_model', 'image', 'queue', 'lookup', 'ragged', 'signal', 'audio', 'test', 'dtypes', 'experimental', 'random', 'sparse', 'feature_column', 'version', 'io', 'math', 'tpu', 'distribute', 'compat', 'errors', 'nn', 'data', '__pycache__', 'train', 'config', 'sets', 'graph_util']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/strings
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/strings/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/summary
# Subdirs:['experimental', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/summary/experimental
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/summary/experimental/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/summary/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/quantization
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/quantization/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/sysconfig
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/sysconfig/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/bitwise
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/bitwise/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/linalg
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/linalg/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/debugging
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/debugging/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/autograph
# Subdirs:['experimental', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/autograph/experimental
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/autograph/experimental/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/autograph/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/xla
# Subdirs:['experimental', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/xla/experimental
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/xla/experimental/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/xla/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/lite
# Subdirs:['experimental', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/lite/experimental
# Subdirs:['microfrontend', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/lite/experimental/microfrontend
# Subdirs:['python', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/lite/experimental/microfrontend/python
# Subdirs:['ops', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/lite/experimental/microfrontend/python/ops
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/lite/experimental/microfrontend/python/ops/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/lite/experimental/microfrontend/python/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/lite/experimental/microfrontend/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/lite/experimental/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/lite/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/raw_ops
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/raw_ops/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/nest
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/nest/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/saved_model
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/saved_model/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/image
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/image/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/queue
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/queue/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/lookup
# Subdirs:['experimental', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/lookup/experimental
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/lookup/experimental/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/lookup/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/ragged
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/ragged/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/signal
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/signal/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/audio
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/audio/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/test
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/test/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/dtypes
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/dtypes/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/experimental
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/experimental/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/random
# Subdirs:['experimental', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/random/experimental
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/random/experimental/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/random/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/sparse
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/sparse/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/feature_column
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/feature_column/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/version
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/version/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/io
# Subdirs:['gfile', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/io/gfile
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/io/gfile/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/io/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/math
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/math/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/tpu
# Subdirs:['experimental', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/tpu/experimental
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/tpu/experimental/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/tpu/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/distribute
# Subdirs:['experimental', '__pycache__', 'cluster_resolver']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/distribute/experimental
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/distribute/experimental/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/distribute/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/distribute/cluster_resolver
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/distribute/cluster_resolver/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/compat
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/compat/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/errors
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/errors/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/nn
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/nn/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/data
# Subdirs:['experimental', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/data/experimental
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/data/experimental/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/data/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/train
# Subdirs:['experimental', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/train/experimental
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/train/experimental/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/train/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/config
# Subdirs:['optimizer', 'experimental', 'threading', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/config/optimizer
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/config/optimizer/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/config/experimental
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/config/experimental/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/config/threading
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/config/threading/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/config/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/sets
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/sets/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/graph_util
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/v2/graph_util/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/compat/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/losses
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/losses/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/errors
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/errors/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/nn
# Subdirs:['rnn_cell', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/nn/rnn_cell
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/nn/rnn_cell/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/nn/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/gfile
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/gfile/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/data
# Subdirs:['experimental', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/data/experimental
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/data/experimental/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/data/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/__pycache__
# Subdirs:[]
# Files:['v1.cpython-37.pyc', '__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/layers
# Subdirs:['experimental', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/layers/experimental
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/layers/experimental/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/layers/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/train
# Subdirs:['queue_runner', 'experimental', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/train/queue_runner
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/train/queue_runner/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/train/experimental
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/train/experimental/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/train/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/config
# Subdirs:['optimizer', 'experimental', 'threading', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/config/optimizer
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/config/optimizer/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/config/experimental
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/config/experimental/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/config/threading
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/config/threading/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/config/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/sets
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/sets/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/metrics
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/metrics/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/graph_util
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/v1/graph_util/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/_api/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/core
# Subdirs:['grappler', 'profiler', 'debug', 'framework', 'kernels', 'example', 'protobuf', 'util', '__pycache__', 'lib']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/core/grappler
# Subdirs:['costs', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/core/grappler/costs
# Subdirs:['__pycache__']
# Files:['op_performance_data_pb2.py', '__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/core/grappler/costs/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc', 'op_performance_data_pb2.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/core/grappler/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/core/profiler
# Subdirs:['__pycache__']
# Files:['tfprof_output_pb2.py', 'profiler_service_pb2_grpc.py', 'op_profile_pb2.py', '__init__.py', 'tfprof_options_pb2.py', 'profiler_analysis_pb2.py', 'profiler_analysis_pb2_grpc.py', 'profiler_service_pb2.py', 'profile_pb2.py', 'tfprof_log_pb2.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/core/profiler/__pycache__
# Subdirs:[]
# Files:['profiler_analysis_pb2.cpython-37.pyc', 'tfprof_options_pb2.cpython-37.pyc', 'op_profile_pb2.cpython-37.pyc', 'tfprof_log_pb2.cpython-37.pyc', '__init__.cpython-37.pyc', 'profile_pb2.cpython-37.pyc', 'tfprof_output_pb2.cpython-37.pyc', 'profiler_service_pb2_grpc.cpython-37.pyc', 'profiler_service_pb2.cpython-37.pyc', 'profiler_analysis_pb2_grpc.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/core/debug
# Subdirs:['__pycache__']
# Files:['debug_service_pb2_grpc.py', 'debugger_event_metadata_pb2.py', 'debug_service_pb2.py', '__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/core/debug/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc', 'debug_service_pb2_grpc.cpython-37.pyc', 'debugger_event_metadata_pb2.cpython-37.pyc', 'debug_service_pb2.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/core/framework
# Subdirs:['__pycache__']
# Files:['variable_pb2.py', 'attr_value_pb2.py', 'kernel_def_pb2.py', 'log_memory_pb2.py', 'op_def_pb2.py', 'summary_pb2.py', 'step_stats_pb2.py', 'graph_transfer_info_pb2.py', 'types_pb2.py', 'graph_pb2.py', 'allocation_description_pb2.py', '__init__.py', 'tensor_pb2.py', 'api_def_pb2.py', 'cost_graph_pb2.py', 'node_def_pb2.py', 'function_pb2.py', 'device_attributes_pb2.py', 'tensor_description_pb2.py', 'versions_pb2.py', 'tensor_slice_pb2.py', 'resource_handle_pb2.py', 'reader_base_pb2.py', 'remote_fused_graph_execute_info_pb2.py', 'tensor_shape_pb2.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/core/framework/__pycache__
# Subdirs:[]
# Files:['kernel_def_pb2.cpython-37.pyc', 'remote_fused_graph_execute_info_pb2.cpython-37.pyc', 'reader_base_pb2.cpython-37.pyc', 'tensor_description_pb2.cpython-37.pyc', 'variable_pb2.cpython-37.pyc', 'cost_graph_pb2.cpython-37.pyc', 'attr_value_pb2.cpython-37.pyc', 'api_def_pb2.cpython-37.pyc', '__init__.cpython-37.pyc', 'device_attributes_pb2.cpython-37.pyc', 'graph_transfer_info_pb2.cpython-37.pyc', 'tensor_pb2.cpython-37.pyc', 'allocation_description_pb2.cpython-37.pyc', 'tensor_slice_pb2.cpython-37.pyc', 'function_pb2.cpython-37.pyc', 'summary_pb2.cpython-37.pyc', 'node_def_pb2.cpython-37.pyc', 'step_stats_pb2.cpython-37.pyc', 'log_memory_pb2.cpython-37.pyc', 'resource_handle_pb2.cpython-37.pyc', 'tensor_shape_pb2.cpython-37.pyc', 'op_def_pb2.cpython-37.pyc', 'types_pb2.cpython-37.pyc', 'graph_pb2.cpython-37.pyc', 'versions_pb2.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/core/kernels
# Subdirs:['boosted_trees', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/core/kernels/boosted_trees
# Subdirs:['__pycache__']
# Files:['__init__.py', 'boosted_trees_pb2.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/core/kernels/boosted_trees/__pycache__
# Subdirs:[]
# Files:['boosted_trees_pb2.cpython-37.pyc', '__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/core/kernels/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/core/example
# Subdirs:['__pycache__']
# Files:['example_parser_configuration_pb2.py', 'feature_pb2.py', '__init__.py', 'example_pb2.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/core/example/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc', 'example_parser_configuration_pb2.cpython-37.pyc', 'feature_pb2.cpython-37.pyc', 'example_pb2.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/core/protobuf
# Subdirs:['tpu', 'data', '__pycache__']
# Files:['control_flow_pb2.py', 'named_tensor_pb2.py', 'meta_graph_pb2.py', 'trackable_object_graph_pb2.py', 'verifier_config_pb2.py', 'queue_runner_pb2.py', 'transport_options_pb2.py', '__init__.py', 'tensor_bundle_pb2.py', 'rewriter_config_pb2.py', 'debug_pb2.py', 'saved_object_graph_pb2.py', 'graph_debug_info_pb2.py', 'trace_events_pb2.py', 'config_pb2.py', 'saved_model_pb2.py', 'saver_pb2.py', 'cluster_pb2.py', 'device_properties_pb2.py', 'tensorflow_server_pb2.py', 'struct_pb2.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/core/protobuf/tpu
# Subdirs:['__pycache__']
# Files:['compilation_result_pb2.py', '__init__.py', 'topology_pb2.py', 'tpu_embedding_configuration_pb2.py', 'dynamic_padding_pb2.py', 'tpu_embedding_output_layout_pb2.py', 'optimization_parameters_pb2.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/core/protobuf/tpu/__pycache__
# Subdirs:[]
# Files:['dynamic_padding_pb2.cpython-37.pyc', 'topology_pb2.cpython-37.pyc', 'tpu_embedding_configuration_pb2.cpython-37.pyc', 'optimization_parameters_pb2.cpython-37.pyc', '__init__.cpython-37.pyc', 'tpu_embedding_output_layout_pb2.cpython-37.pyc', 'compilation_result_pb2.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/core/protobuf/data
# Subdirs:['experimental', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/core/protobuf/data/experimental
# Subdirs:['__pycache__']
# Files:['__init__.py', 'snapshot_pb2.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/core/protobuf/data/experimental/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc', 'snapshot_pb2.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/core/protobuf/data/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/core/protobuf/__pycache__
# Subdirs:[]
# Files:['saver_pb2.cpython-37.pyc', 'queue_runner_pb2.cpython-37.pyc', 'debug_pb2.cpython-37.pyc', 'device_properties_pb2.cpython-37.pyc', 'tensorflow_server_pb2.cpython-37.pyc', 'tensor_bundle_pb2.cpython-37.pyc', '__init__.cpython-37.pyc', 'struct_pb2.cpython-37.pyc', 'saved_model_pb2.cpython-37.pyc', 'rewriter_config_pb2.cpython-37.pyc', 'graph_debug_info_pb2.cpython-37.pyc', 'control_flow_pb2.cpython-37.pyc', 'config_pb2.cpython-37.pyc', 'saved_object_graph_pb2.cpython-37.pyc', 'meta_graph_pb2.cpython-37.pyc', 'trace_events_pb2.cpython-37.pyc', 'named_tensor_pb2.cpython-37.pyc', 'cluster_pb2.cpython-37.pyc', 'verifier_config_pb2.cpython-37.pyc', 'transport_options_pb2.cpython-37.pyc', 'trackable_object_graph_pb2.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/core/util
# Subdirs:['__pycache__']
# Files:['test_log_pb2.py', 'saved_tensor_slice_pb2.py', 'memmapped_file_system_pb2.py', '__init__.py', 'event_pb2.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/core/util/__pycache__
# Subdirs:[]
# Files:['event_pb2.cpython-37.pyc', 'saved_tensor_slice_pb2.cpython-37.pyc', '__init__.cpython-37.pyc', 'memmapped_file_system_pb2.cpython-37.pyc', 'test_log_pb2.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/core/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/core/lib
# Subdirs:['core', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/core/lib/core
# Subdirs:['__pycache__']
# Files:['__init__.py', 'error_codes_pb2.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/core/lib/core/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc', 'error_codes_pb2.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/core/lib/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/compiler
# Subdirs:['xla', 'tf2tensorrt', 'jit', 'tf2xla', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/compiler/xla
# Subdirs:['service', 'python_api', 'experimental', '__pycache__']
# Files:['__init__.py', 'xla_data_pb2.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/compiler/xla/service
# Subdirs:['__pycache__']
# Files:['hlo_pb2.py', '__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/compiler/xla/service/__pycache__
# Subdirs:[]
# Files:['hlo_pb2.cpython-37.pyc', '__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/compiler/xla/python_api
# Subdirs:['__pycache__']
# Files:['xla_shape.py', '__init__.py', 'types.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/compiler/xla/python_api/__pycache__
# Subdirs:[]
# Files:['types.cpython-37.pyc', '__init__.cpython-37.pyc', 'xla_shape.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/compiler/xla/experimental
# Subdirs:['xla_sharding', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/compiler/xla/experimental/xla_sharding
# Subdirs:['__pycache__']
# Files:['xla_sharding.py', '__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/compiler/xla/experimental/xla_sharding/__pycache__
# Subdirs:[]
# Files:['xla_sharding.cpython-37.pyc', '__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/compiler/xla/experimental/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/compiler/xla/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc', 'xla_data_pb2.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/compiler/tf2tensorrt
# Subdirs:['ops', '__pycache__']
# Files:['wrap_py_utils.py', '__init__.py', '_wrap_py_utils.so']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/compiler/tf2tensorrt/ops
# Subdirs:['__pycache__']
# Files:['__init__.py', 'gen_trt_ops.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/compiler/tf2tensorrt/ops/__pycache__
# Subdirs:[]
# Files:['gen_trt_ops.cpython-37.pyc', '__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/compiler/tf2tensorrt/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc', 'wrap_py_utils.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/compiler/jit
# Subdirs:['ops', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/compiler/jit/ops
# Subdirs:['__pycache__']
# Files:['xla_ops_grad.py', '__init__.py', 'xla_ops.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/compiler/jit/ops/__pycache__
# Subdirs:[]
# Files:['xla_ops.cpython-37.pyc', '__init__.cpython-37.pyc', 'xla_ops_grad.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/compiler/jit/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/compiler/tf2xla
# Subdirs:['python', 'ops', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/compiler/tf2xla/python
# Subdirs:['__pycache__']
# Files:['xla.py', '__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/compiler/tf2xla/python/__pycache__
# Subdirs:[]
# Files:['xla.cpython-37.pyc', '__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/compiler/tf2xla/ops
# Subdirs:['__pycache__']
# Files:['gen_xla_ops.py', '__init__.py', '_xla_ops.so']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/compiler/tf2xla/ops/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc', 'gen_xla_ops.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/compiler/tf2xla/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/compiler/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib
# Subdirs:['summary', 'bigtable', 'constrained_optimization', 'eager', 'quantization', 'rnn', 'sparsemax', 'cloud', 'slim', 'keras', 'receptive_field', 'checkpoint', 'tensorboard', 'training', 'tensorrt', 'boosted_trees', 'tensor_forest', 'autograph', 'opt', 'distributions', 'kinesis', 'memory_stats', 'saved_model', 'image', 'fused_conv', 'batching', 'decision_trees', 'linear_optimizer', 'input_pipeline', 'recurrent', 'resampler', 'crf', 'ignite', 'framework', 'tfprof', 'lookup', 'proto', 'cudnn_rnn', 'learn', 'kafka', 'deprecated', 'quantize', 'signal', 'remote_fused_graph', 'seq2seq', 'predictor', 'optimizer_v2', 'cmake', 'reduce_slice_ops', 'labeled_tensor', 'stat_summarizer', 'specs', 'rpc', 'ffmpeg', 'feature_column', 'hooks', 'integrate', 'text', 'graph_editor', 'session_bundle', 'compiler', 'meta_graph_transform', 'libsvm', 'tpu', 'solvers', 'staging', 'bayesflow', 'estimator', 'periodic_resample', 'copy_graph', 'testing', 'distribute', 'util', 'losses', 'stateless', 'grid_rnn', 'mixed_precision', 'timeseries', 'hadoop', 'nn', 'data', '__pycache__', 'factorization', 'cluster_resolver', 'legacy_seq2seq', 'layers', 'kernel_methods', 'all_reduce', 'metrics', 'nearest_neighbor', 'model_pruning']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/summary
# Subdirs:['__pycache__']
# Files:['__init__.py', 'summary.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/summary/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc', 'summary.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/bigtable
# Subdirs:['python', 'ops', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/bigtable/python
# Subdirs:['ops', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/bigtable/python/ops
# Subdirs:['__pycache__']
# Files:['__init__.py', 'bigtable_api.py', '_bigtable.so']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/bigtable/python/ops/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc', 'bigtable_api.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/bigtable/python/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/bigtable/ops
# Subdirs:['__pycache__']
# Files:['__init__.py', 'gen_bigtable_ops.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/bigtable/ops/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc', 'gen_bigtable_ops.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/bigtable/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/constrained_optimization
# Subdirs:['python', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/constrained_optimization/python
# Subdirs:['__pycache__']
# Files:['swap_regret_optimizer.py', 'external_regret_optimizer.py', '__init__.py', 'constrained_optimizer.py', 'constrained_minimization_problem.py', 'candidates.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/constrained_optimization/python/__pycache__
# Subdirs:[]
# Files:['candidates.cpython-37.pyc', 'external_regret_optimizer.cpython-37.pyc', '__init__.cpython-37.pyc', 'constrained_minimization_problem.cpython-37.pyc', 'swap_regret_optimizer.cpython-37.pyc', 'constrained_optimizer.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/constrained_optimization/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/eager
# Subdirs:['python', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/eager/python
# Subdirs:['__pycache__']
# Files:['saver.py', 'metrics.py', 'tfe.py', 'datasets.py', '__init__.py', 'metrics_impl.py', 'parameter_server.py', 'network.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/eager/python/__pycache__
# Subdirs:[]
# Files:['tfe.cpython-37.pyc', 'datasets.cpython-37.pyc', '__init__.cpython-37.pyc', 'network.cpython-37.pyc', 'metrics_impl.cpython-37.pyc', 'saver.cpython-37.pyc', 'parameter_server.cpython-37.pyc', 'metrics.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/eager/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/quantization
# Subdirs:['python', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/quantization/python
# Subdirs:['__pycache__']
# Files:['array_ops.py', 'nn_ops.py', '__init__.py', 'math_ops.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/quantization/python/__pycache__
# Subdirs:[]
# Files:['nn_ops.cpython-37.pyc', 'array_ops.cpython-37.pyc', '__init__.cpython-37.pyc', 'math_ops.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/quantization/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/rnn
# Subdirs:['python', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/rnn/python
# Subdirs:['tools', 'kernel_tests', 'ops', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/rnn/python/tools
# Subdirs:['__pycache__']
# Files:['checkpoint_convert.py', '__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/rnn/python/tools/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc', 'checkpoint_convert.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/rnn/python/kernel_tests
# Subdirs:['__pycache__']
# Files:['benchmarking.py', '__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/rnn/python/kernel_tests/__pycache__
# Subdirs:[]
# Files:['benchmarking.cpython-37.pyc', '__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/rnn/python/ops
# Subdirs:['__pycache__']
# Files:['lstm_ops.py', 'fused_rnn_cell.py', 'core_rnn_cell.py', '__init__.py', 'gru_ops.py', 'rnn_cell.py', 'rnn.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/rnn/python/ops/__pycache__
# Subdirs:[]
# Files:['gru_ops.cpython-37.pyc', 'rnn_cell.cpython-37.pyc', '__init__.cpython-37.pyc', 'rnn.cpython-37.pyc', 'core_rnn_cell.cpython-37.pyc', 'lstm_ops.cpython-37.pyc', 'fused_rnn_cell.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/rnn/python/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/rnn/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/sparsemax
# Subdirs:['python', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/sparsemax/python
# Subdirs:['ops', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/sparsemax/python/ops
# Subdirs:['__pycache__']
# Files:['__init__.py', 'sparsemax_loss.py', 'sparsemax.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/sparsemax/python/ops/__pycache__
# Subdirs:[]
# Files:['sparsemax.cpython-37.pyc', '__init__.cpython-37.pyc', 'sparsemax_loss.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/sparsemax/python/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/sparsemax/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/cloud
# Subdirs:['python', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/cloud/python
# Subdirs:['ops', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/cloud/python/ops
# Subdirs:['__pycache__']
# Files:['gcs_config_ops.py', 'gen_bigquery_reader_ops.py', '__init__.py', 'gen_gcs_config_ops.py', 'bigquery_reader_ops.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/cloud/python/ops/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc', 'gen_gcs_config_ops.cpython-37.pyc', 'gen_bigquery_reader_ops.cpython-37.pyc', 'bigquery_reader_ops.cpython-37.pyc', 'gcs_config_ops.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/cloud/python/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/cloud/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/slim
# Subdirs:['python', '__pycache__']
# Files:['__init__.py', 'nets.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/slim/python
# Subdirs:['slim', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/slim/python/slim
# Subdirs:['nets', 'data', '__pycache__']
# Files:['learning.py', 'model_analyzer.py', 'evaluation.py', '__init__.py', 'queues.py', 'summaries.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/slim/python/slim/nets
# Subdirs:['__pycache__']
# Files:['inception_v2.py', 'vgg.py', 'resnet_utils.py', '__init__.py', 'alexnet.py', 'inception.py', 'inception_v1.py', 'inception_v3.py', 'overfeat.py', 'resnet_v1.py', 'resnet_v2.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/slim/python/slim/nets/__pycache__
# Subdirs:[]
# Files:['overfeat.cpython-37.pyc', 'inception_v3.cpython-37.pyc', 'alexnet.cpython-37.pyc', '__init__.cpython-37.pyc', 'resnet_v1.cpython-37.pyc', 'vgg.cpython-37.pyc', 'resnet_v2.cpython-37.pyc', 'inception_v1.cpython-37.pyc', 'inception.cpython-37.pyc', 'resnet_utils.cpython-37.pyc', 'inception_v2.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/slim/python/slim/data
# Subdirs:['__pycache__']
# Files:['dataset_data_provider.py', 'prefetch_queue.py', 'data_provider.py', '__init__.py', 'tfexample_decoder.py', 'parallel_reader.py', 'dataset.py', 'data_decoder.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/slim/python/slim/data/__pycache__
# Subdirs:[]
# Files:['data_decoder.cpython-37.pyc', 'dataset.cpython-37.pyc', '__init__.cpython-37.pyc', 'prefetch_queue.cpython-37.pyc', 'parallel_reader.cpython-37.pyc', 'dataset_data_provider.cpython-37.pyc', 'tfexample_decoder.cpython-37.pyc', 'data_provider.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/slim/python/slim/__pycache__
# Subdirs:[]
# Files:['evaluation.cpython-37.pyc', 'learning.cpython-37.pyc', '__init__.cpython-37.pyc', 'queues.cpython-37.pyc', 'model_analyzer.cpython-37.pyc', 'summaries.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/slim/python/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/slim/__pycache__
# Subdirs:[]
# Files:['nets.cpython-37.pyc', '__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/keras
# Subdirs:['api', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/keras/api
# Subdirs:['keras', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/keras/api/keras
# Subdirs:['applications', 'utils', 'optimizers', 'initializers', 'wrappers', 'datasets', 'constraints', 'regularizers', 'models', 'preprocessing', 'callbacks', 'losses', '__pycache__', 'backend', 'activations', 'layers', 'metrics']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/keras/api/keras/applications
# Subdirs:['inception_v3', 'vgg16', 'vgg19', 'mobilenet', '__pycache__', 'resnet50', 'xception']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_core/contrib/keras/api/keras/applications/inception_v3
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# ...
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_estimator/_api/v2/estimator/experimental/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_estimator/_api/v2/estimator/export
# Subdirs:['__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_estimator/_api/v2/estimator/export/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_estimator/_api/v2/estimator/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_estimator/_api/v2/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc', 'v2.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_estimator/_api/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_estimator/contrib
# Subdirs:['estimator', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_estimator/contrib/estimator
# Subdirs:['python', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_estimator/contrib/estimator/python
# Subdirs:['estimator', '__pycache__']
# Files:['__init__.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_estimator/contrib/estimator/python/estimator
# Subdirs:['__pycache__']
# Files:['replicate_model_fn.py', 'logit_fns.py', '__init__.py', 'export.py', 'boosted_trees.py', 'dnn_with_layer_annotations.py', 'multi_head.py', 'saved_model_estimator.py', 'exporter.py', 'head.py', 'rnn.py', 'extenders.py']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_estimator/contrib/estimator/python/estimator/__pycache__
# Subdirs:[]
# Files:['export.cpython-37.pyc', 'logit_fns.cpython-37.pyc', 'exporter.cpython-37.pyc', 'multi_head.cpython-37.pyc', '__init__.cpython-37.pyc', 'boosted_trees.cpython-37.pyc', 'rnn.cpython-37.pyc', 'head.cpython-37.pyc', 'dnn_with_layer_annotations.cpython-37.pyc', 'extenders.cpython-37.pyc', 'saved_model_estimator.cpython-37.pyc', 'replicate_model_fn.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_estimator/contrib/estimator/python/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_estimator/contrib/estimator/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_estimator/contrib/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_estimator/__pycache__
# Subdirs:[]
# Files:['__init__.cpython-37.pyc']
#
# Root:/tensorflow-1.15.2/python3.7/tensorflow_probability-0.7.0.dist-info
# Subdirs:[]
# Files:['RECORD', 'INSTALLER', 'METADATA', 'REQUESTED', 'WHEEL', 'top_level.txt']
#
# Root:/python-apt
# Subdirs:['aptsources', 'utils', 'debian', 'typehinting', 'python', 'doc', 'tests', 'build', 'apt', 'po', 'data', '.git']
# Files:['setup.py', 'COPYING.GPL', '.gitlab-ci.yml', 'TODO', 'AUTHORS', 'Dockerfile', 'setup.cfg', 'README.md', 'pre-build.sh', '.travis.yml']
#
# Root:/python-apt/aptsources
# Subdirs:[]
# Files:['__init__.py', 'distro.py', 'sourceslist.py', 'distinfo.py']
#
# Root:/python-apt/utils
# Subdirs:[]
# Files:['get_debian_mirrors.py', 'pyversions', 'get_ubuntu_mirrors_from_lp.py', 'mirrortest']
#
# Root:/python-apt/debian
# Subdirs:['source', 'tests']
# Files:['python-apt-doc.links', 'python-apt-common.install', 'python-apt-dbg.install', 'gbp.conf', 'python3-apt-dbg.files', 'python-apt-doc.examples', 'copyright', 'python-apt.docs', 'python3-apt.install', 'python-apt.install', 'python-apt-doc.maintscript', 'python-apt-doc.doc-base', 'control', 'python-apt-dev.maintscript', 'python-apt-dev.examples', 'changelog', 'python-apt-doc.docs', 'rules', 'python-apt-doc.preinst', 'compat', 'python-apt-dev.install']
#
# Root:/python-apt/debian/source
# Subdirs:[]
# Files:['format']
#
# Root:/python-apt/debian/tests
# Subdirs:[]
# Files:['control', 'run-tests']
#
# Root:/python-apt/typehinting
# Subdirs:[]
# Files:['apt_pkg.pyi', 'apt_inst.pyi']
#
# Root:/python-apt/python
# Subdirs:[]
# Files:['sourcelist.cc', 'depcache.cc', 'cachegroup.cc', 'metaindex.cc', 'pkgrecords.cc', 'hashes.cc', 'cache.cc', 'python-apt-helpers.cc', 'configuration.cc', 'generic.h', 'generic.cc', 'orderlist.cc', 'tag.cc', 'hashstringlist.cc', 'progress.cc', 'indexfile.cc', 'apt_pkgmodule.h', 'python-apt.h', 'string.cc', 'acquire.cc', 'lock.cc', 'pkgrecords.h', 'apt_pkgmodule.cc', 'hashstring.cc', 'apt_instmodule.h', 'tarfile.cc', 'cdrom.cc', 'policy.cc', 'arfile.cc', 'pkgmanager.cc', 'apt_instmodule.cc', 'progress.h', 'acquire-item.cc', 'pkgsrcrecords.cc']
#
# Root:/python-apt/doc
# Subdirs:['examples', 'source']
# Files:['client-example.cc', 'Makefile']
#
# Root:/python-apt/doc/examples
# Subdirs:[]
# Files:['print_uris.py', 'build-deps.py', 'checkstate.py', 'sources.py', 'tagfile.py', 'config.py', 'update.py', 'records.py', 'metaindex.py', 'acquire.py', 'action.py', 'versiontest.py', 'inst.py', 'architecture.py', 'progress.py', 'indexfile.py', 'configisc.py', 'depcache.py', 'cdrom.py', 'all_deps.py', 'build-deps-old.py', 'recommends.py', 'dependant-pkgs.py', 'desc.py', 'deb_inspect.py']
#
# Root:/python-apt/doc/source
# Subdirs:['library', 'examples', 'c++', 'tutorials', 'templates', 'whatsnew']
# Files:['conf.py', 'contents.rst']
#
# Root:/python-apt/doc/source/library
# Subdirs:[]
# Files:['apt.cdrom.rst', 'aptsources.sourceslist.rst', 'apt.progress.base.rst', 'apt_pkg.rst', 'apt_inst.rst', 'index.rst', 'apt.package.rst', 'apt.debfile.rst', 'apt.progress.text.rst', 'aptsources.distro.rst', 'apt.cache.rst', 'aptsources.distinfo.rst']
#
# Root:/python-apt/doc/source/examples
# Subdirs:[]
# Files:['dpkg-extract.py', 'dpkg-info.py', 'apt-cdrom.py', 'update-print-uris.py', 'dpkg-contents.py', 'missing-deps.py', 'cache-packages.py', 'cache-pkgfile.py']
#
# Root:/python-apt/doc/source/c++
# Subdirs:[]
# Files:['api.rst', 'embedding.rst', 'index.rst']
#
# Root:/python-apt/doc/source/tutorials
# Subdirs:[]
# Files:['apt-get.rst', 'apt-cdrom.rst', 'contributing.rst', 'index.rst']
#
# Root:/python-apt/doc/source/templates
# Subdirs:[]
# Files:['indexcontent.html', 'layout.html']
#
# Root:/python-apt/doc/source/whatsnew
# Subdirs:[]
# Files:['1.0.rst', '0.9.4.rst', '0.8.0.rst', '1.1.rst', 'index.rst', '1.4.rst', '0.7.100.rst', '1.6.rst', '1.7.rst']
#
# Root:/python-apt/tests
# Subdirs:['old', 'data']
# Files:['test_cve_2020_27351.py', 'test_configuration.py', 'test_all.py', 'test_aptsources_ports.py', 'test_debfile.py', 'testmanual_pep8.py', '__init__.py', 'test_deps.py', 'test_tagfile.py', 'test_group.py', 'test_signed_usable.py', 'test_cache_invocation.py', 'test_lp659438.py', 'test_hashsums.py', 'test_pyflakes.py', 'test_aptsources.py', 'test_paths.py', 'test_pep484.py', 'test_debfile_multiarch.py', 'test_progress.py', 'testcommon.py', 'test_apt_cache.py', 'test_utils.py', 'test_large_file.py', 'fakeroot-apt-key', 'test_sourcerecords.py', 'test_policy.py', 'test_auth.py', 'test_hashes.py', 'test_size_to_str.py']
#
# Root:/python-apt/tests/old
# Subdirs:[]
# Files:['memleak.py', '__init__.py', 'refcount.py', 'pkgrecords.py', 'apt-test.py', 'pkgsrcrecords.py', 'lock.py', 'depcache.py', 'pkgproblemresolver.py', 'test_enhances.py', 'cache.py']
#
# Root:/python-apt/tests/data
# Subdirs:['test-provides', 'aptsources', 'test-repo2', 'fake-packages', 'misc', 'hashsums', 'tagfile', 'test_debs', 'test-source-repo', 'test-repo', 'test-signed-usable-repo', 'aptsources_ports']
# Files:[]
#
# Root:/python-apt/tests/data/test-provides
# Subdirs:['var', 'etc']
# Files:[]
#
# Root:/python-apt/tests/data/test-provides/var
# Subdirs:['lib']
# Files:[]
#
# Root:/python-apt/tests/data/test-provides/var/lib
# Subdirs:['apt', 'dpkg']
# Files:[]
#
# Root:/python-apt/tests/data/test-provides/var/lib/apt
# Subdirs:['lists']
# Files:[]
#
# Root:/python-apt/tests/data/test-provides/var/lib/apt/lists
# Subdirs:[]
# Files:['archive.ubuntu.com_ubuntu_dists_oneiric_main_binary-i386_Packages']
#
# Root:/python-apt/tests/data/test-provides/var/lib/dpkg
# Subdirs:[]
# Files:['status']
#
# Root:/python-apt/tests/data/test-provides/etc
# Subdirs:['apt']
# Files:[]
#
# Root:/python-apt/tests/data/test-provides/etc/apt
# Subdirs:[]
# Files:['sources.list']
#
# Root:/python-apt/tests/data/aptsources
# Subdirs:[]
# Files:['sources.list', 'os-release', 'lsb-release', 'sources.list.testDuplication', 'sources.list.testDistribution']
#
# Root:/python-apt/tests/data/test-repo2
# Subdirs:[]
# Files:['Packages.gz']
#
# Root:/python-apt/tests/data/fake-packages
# Subdirs:[]
# Files:['Packages.gz', 'Packages']
#
# Root:/python-apt/tests/data/misc
# Subdirs:[]
# Files:['foo_Release']
#
# Root:/python-apt/tests/data/hashsums
# Subdirs:[]
# Files:['hashsum_test_with_zero.data', 'hashsum_test.data']
#
# Root:/python-apt/tests/data/tagfile
# Subdirs:[]
# Files:['history.1.log.gz', 'history.log']
#
# Root:/python-apt/tests/data/test_debs
# Subdirs:['var', 'etc']
# Files:['multiarch-test1_i386.deb', 'large-package-content_1.0_all.deb', 'testdep-allowed-any_1.0-1_i386.deb', 'data-tar-broken.deb', 'gdebi-test9.deb', 'data-tar-xz.deb', 'gdebi-test8.deb', 'gdebi-test6.deb', 'impossible-build-depends_2.5-1.dsc', 'gdebi-test11.deb', 'gdebi-test4.deb', 'gdebi-test2.deb', 'gdebi-test1.deb', 'gdebi-test5.deb', 'testdep-same-arch_1.0-1_i386.deb', 'hello_2.5-1.dsc', 'gdebi-test10.deb', 'gdebi-test3.deb', 'gdebi-test13.deb', 'gdebi-test7.deb', 'gdebi-test12.deb', 'data-tar.deb', 'utf8-package_1.0-1_all.deb']
#
# Root:/python-apt/tests/data/test_debs/var
# Subdirs:['lib']
# Files:[]
#
# Root:/python-apt/tests/data/test_debs/var/lib
# Subdirs:['apt', 'dpkg']
# Files:[]
#
# Root:/python-apt/tests/data/test_debs/var/lib/apt
# Subdirs:['lists']
# Files:[]
#
# Root:/python-apt/tests/data/test_debs/var/lib/apt/lists
# Subdirs:[]
# Files:['archive.ubuntu.com_ubuntu_dists_maverick_main_binary-i386_Packages']
#
# Root:/python-apt/tests/data/test_debs/var/lib/dpkg
# Subdirs:[]
# Files:['status']
#
# Root:/python-apt/tests/data/test_debs/etc
# Subdirs:['apt']
# Files:[]
#
# Root:/python-apt/tests/data/test_debs/etc/apt
# Subdirs:[]
# Files:['sources.list']
#
# Root:/python-apt/tests/data/test-source-repo
# Subdirs:[]
# Files:['Sources']
#
# Root:/python-apt/tests/data/test-repo
# Subdirs:[]
# Files:['Packages.gz']
#
# Root:/python-apt/tests/data/test-signed-usable-repo
# Subdirs:['signed', 'unsigned']
# Files:['seckey.asc', 'key.gpg.base64']
#
# Root:/python-apt/tests/data/test-signed-usable-repo/signed
# Subdirs:[]
# Files:['signed-not-usable_1.0.dsc', 'signed-usable_1.0_all.deb', 'signed-usable_1.0.dsc', 'Release.gpg', 'Packages', 'Sources', 'signed-not-usable_1.0_all.deb', 'Release']
#
# Root:/python-apt/tests/data/test-signed-usable-repo/unsigned
# Subdirs:[]
# Files:['unsigned-unusable_1.0_all.deb', 'unsigned-usable_1.0.dsc', 'unsigned-not-usable_1.0.dsc', 'Packages', 'Sources', 'Release', 'unsigned-usable_1.0_all.deb']
#
# Root:/python-apt/tests/data/aptsources_ports
# Subdirs:[]
# Files:['sources.list']
#
# Root:/python-apt/build
# Subdirs:['temp.linux-x86_64-3.7', 'lib.linux-x86_64-3.7', 'data']
# Files:[]
#
# Root:/python-apt/build/temp.linux-x86_64-3.7
# Subdirs:['python']
# Files:[]
#
# Root:/python-apt/build/temp.linux-x86_64-3.7/python
# Subdirs:[]
# Files:['policy.o', 'python-apt-helpers.o', 'acquire.o', 'cdrom.o', 'cache.o', 'arfile.o', 'pkgrecords.o', 'hashstring.o', 'hashstringlist.o', 'acquire-item.o', 'sourcelist.o', 'cachegroup.o', 'progress.o', 'metaindex.o', 'generic.o', 'configuration.o', 'apt_pkgmodule.o', 'tag.o', 'pkgmanager.o', 'apt_instmodule.o', 'pkgsrcrecords.o', 'tarfile.o', 'string.o', 'indexfile.o', 'depcache.o', 'lock.o', 'hashes.o', 'orderlist.o']
#
# Root:/python-apt/build/lib.linux-x86_64-3.7
# Subdirs:['aptsources', 'apt']
# Files:['apt_inst.cpython-37m-x86_64-linux-gnu.so', 'apt_pkg.cpython-37m-x86_64-linux-gnu.so']
#
# Root:/python-apt/build/lib.linux-x86_64-3.7/aptsources
# Subdirs:[]
# Files:['__init__.py', 'distro.py', 'sourceslist.py', 'distinfo.py']
#
# Root:/python-apt/build/lib.linux-x86_64-3.7/apt
# Subdirs:['progress']
# Files:['__init__.py', 'debfile.py', 'package.py', 'utils.py', 'cdrom.py', 'cache.py', 'auth.py']
#
# Root:/python-apt/build/lib.linux-x86_64-3.7/apt/progress
# Subdirs:[]
# Files:['base.py', '__init__.py', 'text.py']
#
# Root:/python-apt/build/data
# Subdirs:['templates']
# Files:[]
#
# Root:/python-apt/build/data/templates
# Subdirs:[]
# Files:['Ubuntu.info', 'Blankon.mirrors', 'Tanglu.info', 'Debian.info', 'gNewSense.mirrors', 'Tanglu.mirrors', 'Debian.mirrors', 'gNewSense.info', 'Ubuntu.mirrors', 'Blankon.info']
#
# Root:/python-apt/apt
# Subdirs:['progress']
# Files:['__init__.py', 'debfile.py', 'package.py', 'utils.py', 'cdrom.py', 'cache.py', 'auth.py']
#
# Root:/python-apt/apt/progress
# Subdirs:[]
# Files:['base.py', '__init__.py', 'text.py']
#
# Root:/python-apt/po
# Subdirs:[]
# Files:['csb.po', 'cs.po', 'python-apt.pot', 'it.po', 'ja.po', 'he.po', 'uk.po', 'id.po', 'el.po', 'ne.po', 'sr.po', 'de.po', 'pt.po', 'hr.po', 'bg.po', 'ko.po', 'ru.po', 'es.po', 'tl.po', 'vi.po', 'zh_TW.po', 'en_AU.po', 'pt_BR.po', 'ca.po', 'ku.po', 'sl.po', 'sq.po', 'lt.po', 'ar.po', 'oc.po', 'bn.po', 'da.po', 'sk.po', 'pl.po', 'ka.po', 'zh_CN.po', 'tr.po', 'eo.po', 'hu.po', 'mk.po', 'gl.po', 'fi.po', 'be.po', 'fr.po', 'nl.po', 'POTFILES.in', 'nb.po', 'th.po', 'zh_HK.po', 'lv.po', 'sv.po', 'en_CA.po', 'ro.po']
#
# Root:/python-apt/data
# Subdirs:['templates']
# Files:[]
#
# Root:/python-apt/data/templates
# Subdirs:[]
# Files:['Ubuntu.info.in', 'Blankon.mirrors', 'gNewSense.info.in', 'Debian.info.in', 'gNewSense.mirrors', 'Tanglu.info.in', 'README.templates', 'Tanglu.mirrors', 'Debian.mirrors', 'Ubuntu.mirrors', 'Blankon.info.in']
#
# Root:/python-apt/.git
# Subdirs:['objects', 'refs', 'logs', 'hooks', 'branches', 'info']
# Files:['HEAD', 'description', 'packed-refs', 'index', 'config']
#
# Root:/python-apt/.git/objects
# Subdirs:['pack', 'info']
# Files:[]
#
# Root:/python-apt/.git/objects/pack
# Subdirs:[]
# Files:['pack-ba2fffb4111e252cadaf1be9207aa51533f9c6ec.pack', 'pack-ba2fffb4111e252cadaf1be9207aa51533f9c6ec.idx']
#
# Root:/python-apt/.git/objects/info
# Subdirs:[]
# Files:[]
#
# Root:/python-apt/.git/refs
# Subdirs:['heads', 'remotes', 'tags']
# Files:[]
#
# Root:/python-apt/.git/refs/heads
# Subdirs:['applied']
# Files:[]
#
# Root:/python-apt/.git/refs/heads/applied
# Subdirs:['ubuntu']
# Files:[]
#
# Root:/python-apt/.git/refs/heads/applied/ubuntu
# Subdirs:[]
# Files:['bionic-security']
#
# Root:/python-apt/.git/refs/remotes
# Subdirs:['origin']
# Files:[]
#
# Root:/python-apt/.git/refs/remotes/origin
# Subdirs:[]
# Files:['HEAD']
#
# Root:/python-apt/.git/refs/tags
# Subdirs:[]
# Files:[]
#
# Root:/python-apt/.git/logs
# Subdirs:['refs']
# Files:['HEAD']
#
# Root:/python-apt/.git/logs/refs
# Subdirs:['heads', 'remotes']
# Files:[]
#
# Root:/python-apt/.git/logs/refs/heads
# Subdirs:['applied']
# Files:[]
#
# Root:/python-apt/.git/logs/refs/heads/applied
# Subdirs:['ubuntu']
# Files:[]
#
# Root:/python-apt/.git/logs/refs/heads/applied/ubuntu
# Subdirs:[]
# Files:['bionic-security']
#
# Root:/python-apt/.git/logs/refs/remotes
# Subdirs:['origin']
# Files:[]
#
# Root:/python-apt/.git/logs/refs/remotes/origin
# Subdirs:[]
# Files:['HEAD']
#
# Root:/python-apt/.git/hooks
# Subdirs:[]
# Files:['pre-push.sample', 'fsmonitor-watchman.sample', 'pre-commit.sample', 'pre-rebase.sample', 'update.sample', 'prepare-commit-msg.sample', 'pre-receive.sample', 'pre-applypatch.sample', 'post-update.sample', 'commit-msg.sample', 'applypatch-msg.sample']
#
# Root:/python-apt/.git/branches
# Subdirs:[]
# Files:[]
#
# Root:/python-apt/.git/info
# Subdirs:[]
# Files:['exclude']
#
# Root:/lib32
# Subdirs:[]
# Files:['libm-2.27.so', 'libnss_hesiod-2.27.so', 'libnss_nis-2.27.so', 'libBrokenLocale-2.27.so', 'libnss_files-2.27.so', 'ld-2.27.so', 'libnss_nis.so.2', 'libcidn-2.27.so', 'libnsl-2.27.so', 'libresolv-2.27.so', 'libpthread.so.0', 'libcidn.so.1', 'libcrypt.so.1', 'librt.so.1', 'libnss_nisplus-2.27.so', 'libnsl.so.1', 'libutil-2.27.so', 'libBrokenLocale.so.1', 'libnss_hesiod.so.2', 'libmemusage.so', 'libutil.so.1', 'libanl-2.27.so', 'libc.so.6', 'libcrypt-2.27.so', 'libc-2.27.so', 'libthread_db-1.0.so', 'libnss_compat-2.27.so', 'libresolv.so.2', 'libdl.so.2', 'librt-2.27.so', 'libSegFault.so', 'libnss_dns.so.2', 'libanl.so.1', 'libnss_dns-2.27.so', 'ld-linux.so.2', 'libthread_db.so.1', 'libm.so.6', 'libpcprofile.so', 'libdl-2.27.so', 'libpthread-2.27.so', 'libnss_files.so.2', 'libnss_nisplus.so.2', 'libnss_compat.so.2']

# %% [markdown]
# # Reading/Writing to files and context managers
# To write to a file in python we can use the built-in `open` function. This function expects 2 arguments:
# - `Filename`: The name of the file (duh)
# - `Mode`: Specifies if you want to read or write to the file
#
# **To write to a file use `'w'` (if it doesn't exist, it will be created) and to read a file use `'r'`.**
#
# ```python
# file = open('test.txt', 'w')
# file.write("This is me writing to a file")
# file.close()
#
# file = open("test.txt", 'r')
# content = file.read()
# file.close()
# print(content) -> "This is me writing to a file"
# ```
# **Notice how in order to read/write to a file we have to both manually open and close the file. You should not open files this way**
#
#
# ## How to actually open to files
# In python, a context manager creates a runtime context that allows you to run a group of statements under a given context. What this means in plain english is that ***`a context manager allows you to run a block of code under certain conditions that allow for the safe management of resources without you having to write code to manage these resources`***. This is especially useful when working with files because any read/write operation requires that you open then close the file, which can cause problems if not done properly. In order to use a context manager, use the `with` keyword:
#
# ```python
# with open('test.txt', 'w') as file:
#     file.write("This is how you should actually write to a file")
# ```
#
# ## What does this mean and why is it better?
# Lets break this down piece by piece.
# - `with open('test.txt', 'w')`: ***'within the context of the open function, open the file "test.txt" and prepare it to have data written to it'***
# - `as file`: ***The current context is opening a file and I want to reference the opened file as 'file'***
# - `file.write()`: ***Write my data to the file***
#
# Opening files this way is much much better because the context manager takes care of closing the file for us, even an error occurs. That makes this method much safer because not closing a file can lead to many problems that I won't go into detail about, but you can look at them [here](https://stackoverflow.com/questions/25070854/why-should-i-close-files-in-python)

# %%
#TODO create the file 'read_me.txt' and write 'You've successfully read this file' then read the file and print the contents of it.
with open("read_me.txt","w") as file:
  file.write("You've successfully read from this file")

# %%
with open("read_me.txt","r") as file:
  content = file.read()
content
# Out:
# "You've successfully read from this file"

# %% [markdown]
# # JSON and storing data
# Writing data to a text file means that you are simply dumping everything into a file with little to no formatting. For simple one line statements this is ok, but for larger data structures, this is not ideal. Imagine having to write data to a file for our bank project. In order to get this data back into a useable python data structure requires more code than if you were to store data as something like `key:value` pairs. `JSON` or javascript object notation, is a way to do exactly that. A json file can be easily loaded to or from a python dictionary because it *is* a python dictionary. All we have to do is import the `json` module.
#
# ```python
# import json
# ```
#
# # Reading and writing to json
# When we import the `json` module, the 2 methods you should get familiar with are `json.dump` and `json.load`.
# - `json.dump(data, file)`: will save a dictionary as a json file
# - `json.load(file)`: will load a json file as a dictionary
#
# ```python
# # saving a json file
# data = {
#     'name': "Gabe",
#     'age': 22,
#     'fav_food': 'shrimp alfredo'
# }
#
# with open('data.json', 'w') as file:
#     json.dump(data, file, indent = 2)
#
#
# # loading a json file
# with open('data.json','r') as file:
#     data = json.load(file)
# ```

# %%
#TODO create a python dictionary and write it to a json file
data = {
    "name":"Oliver",
    "age":15,
    "food":"Hamburger"
}
data
# Out:
# {'age': 15, 'food': 'Hamburger', 'name': 'Oliver'}

# %%
import json
with open("directory1/data.json","w") as file:
  json.dump(data,file, indent = 4)

# %%
with open("directory1/data.json","r") as file:
  content = json.load(file)
content
# Out:
# {'age': 15, 'food': 'Hamburger', 'name': 'Oliver'}
